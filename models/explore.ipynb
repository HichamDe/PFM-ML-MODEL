# %%
import pandas as pd
import missingno as mgn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
# Export model
import os
import joblib
from sklearn.ensemble import RandomForestClassifier
import re
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv("../data/cleaned_set.csv")
df.head()
# Out:
#     price  model_year transmission fuel_type   mileage          brand  \
# 0  280000      2022.0  Automatique    Diesel   97499.5     Volkswagen
# 1  196000      2018.0  Automatique    Diesel  134999.5           Ford
# 2  159000      2021.0  Automatique    Diesel   97499.5          Dacia
# 3  510000      2021.0  Automatique    Diesel   87499.5     Land Rover
# 4  365000      2020.0  Automatique    Diesel  144999.5  Mercedes-Benz
#
#                model  number_of_doors       origin  first_owner  ...  \
# 0              T-Roc                5  WW au Maroc         True  ...
# 1               Kuga                5  WW au Maroc        False  ...
# 2             Duster                5  WW au Maroc        False  ...
# 3  Range Rover Sport                5  WW au Maroc        False  ...
# 4           Classe E                5    Dédouanée        False  ...
#
#    onboard_computer parking_sensors  cruise_control  leather_seats  \
# 0             False           False           False          False
# 1             False           False           False          False
# 2              True            True            True          False
# 3              True            True            True           True
# 4              True            True            True           True
#
#    navigation_gps  sunroof  remote_central_locking  power_windows  price_log  \
# 0           False    False                   False          False     280000
# 1           False    False                   False          False     196000
# 2            True    False                    True           True     159000
# 3            True     True                    True           True     408500
# 4            True     True                    True           True     365000
#
#    car_age
# 0      3.0
# 1      7.0
# 2      4.0
# 3      4.0
# 4      5.0
#
# [5 rows x 30 columns]

# %%
mgn.bar(df)
# Out:
# <Axes: >

# %%
plt.title("Handle Origin Distribution")
plt.hist(df["origin"])
plt.show()

# %%
plt.title("First Owner Distribution")
plt.hist(df["first_owner"])
plt.show()
# Out:
# c:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axes\_axes.py:7093: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_histograms_impl.py:350, in _unsigned_subtract(a, b)
#     349 try:
# --> 350     unsigned_dt = signed_to_unsigned[dt.type]
#     351 except KeyError:
#
# KeyError: <class 'numpy.bool'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 plt.title("First Owner Distribution")
# ----> 2 plt.hist(df["first_owner"])
#       3 plt.show()
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:3469, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3444 @_copy_docstring_and_deprecators(Axes.hist)
#    3445 def hist(
#    3446     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3467     BarContainer | Polygon | list[BarContainer | Polygon],
#    3468 ]:
# -> 3469     return gca().hist(
#    3470         x,
#    3471         bins=bins,
#    3472         range=range,
#    3473         density=density,
#    3474         weights=weights,
#    3475         cumulative=cumulative,
#    3476         bottom=bottom,
#    3477         histtype=histtype,
#    3478         align=align,
#    3479         orientation=orientation,
#    3480         rwidth=rwidth,
#    3481         log=log,
#    3482         color=color,
#    3483         label=label,
#    3484         stacked=stacked,
#    3485         **({"data": data} if data is not None else {}),
#    3486         **kwargs,
#    3487     )
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axes\_axes.py:7093, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7089 # Loop through datasets
#    7090 for i in range(nx):
#    7091     # this will automatically overwrite bins,
#    7092     # so that each histogram uses the same bins
# -> 7093     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7094     tops.append(m)
#    7095 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_histograms_impl.py:827, in histogram(a, bins, range, density, weights)
#     825 # Pre-compute histogram scaling factor
#     826 norm_numerator = n_equal_bins
# --> 827 norm_denom = _unsigned_subtract(last_edge, first_edge)
#     829 # We iterate over blocks here for two reasons: the first is that for
#     830 # large arrays, it is actually faster (for example for a 10^8 array it
#     831 # is 2x as fast) and it results in a memory footprint 3x lower in the
#     832 # limit of large arrays.
#     833 for i in _range(0, len(a), BLOCK):
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_histograms_impl.py:352, in _unsigned_subtract(a, b)
#     350     unsigned_dt = signed_to_unsigned[dt.type]
#     351 except KeyError:
# --> 352     return np.subtract(a, b, dtype=dt)
#     353 else:
#     354     # we know the inputs are integers, and we are deliberately casting
#     355     # signed to unsigned.  The input may be negative python integers so
#     356     # ensure we pass in arrays with the initial dtype (related to NEP 50).
#     357     return np.subtract(np.asarray(a, dtype=dt), np.asarray(b, dtype=dt),
#     358                        casting='unsafe', dtype=unsigned_dt)
#
# TypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
print(f"Null Values: {df.isnull().sum()}")
# mgn.bar(df)
# Out:
# Null Values: price                     0
# model_year                0
# transmission              0
# fuel_type                 0
# mileage                   0
# brand                     0
# model                     0
# number_of_doors           0
# origin                    0
# first_owner               0
# tax_horsepower            0
# condition                 0
# abs                       0
# airbags                   0
# multimedia                0
# backup_camera             0
# air_conditioning          0
# esp                       0
# aluminum_wheels           0
# speed_limiter             0
# onboard_computer          0
# parking_sensors           0
# cruise_control            0
# leather_seats             0
# navigation_gps            0
# sunroof                   0
# remote_central_locking    0
# power_windows             0
# price_log                 0
# car_age                   0
# dtype: int64

# %%
figs,axes = plt.subplots(1,2,figsize=(12,6))

axes[0].boxplot(df["price"])

axes[1].hist(df["price"],bins=50)

plt.tight_layout()                 # Optional: add gridlines
plt.show()

# %%
figs,axes = plt.subplots(1,2,figsize=(12,6))

axes[0].boxplot(df["price_log"])

axes[1].hist(df["price_log"],bins=50)

plt.tight_layout()                 # Optional: add gridlines
plt.show()
