# %%
import pandas as pd
import missingno as mgn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
# Export model
import os
import joblib
from sklearn.ensemble import RandomForestClassifier
import re
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv("../data/cleaned_set.csv")
df.head()
# Out:
#     price  model_year transmission fuel_type   mileage          brand  \
# 0  280000      2022.0  Automatique    Diesel   97499.5     Volkswagen
# 1  196000      2018.0  Automatique    Diesel  134999.5           Ford
# 2  159000      2021.0  Automatique    Diesel   97499.5          Dacia
# 3  408500      2021.0  Automatique    Diesel   87499.5     Land Rover
# 4  365000      2020.0  Automatique    Diesel  144999.5  Mercedes-Benz
#
#                model  number_of_doors       origin  first_owner  ...  \
# 0              T-Roc                5  WW au Maroc         True  ...
# 1               Kuga                5  WW au Maroc        False  ...
# 2             Duster                5  WW au Maroc        False  ...
# 3  Range Rover Sport                5  WW au Maroc        False  ...
# 4           Classe E                5    Dédouanée        False  ...
#
#    speed_limiter onboard_computer  parking_sensors  cruise_control  \
# 0          False            False            False           False
# 1          False            False            False           False
# 2           True             True             True            True
# 3           True             True             True            True
# 4           True             True             True            True
#
#    leather_seats  navigation_gps  sunroof  remote_central_locking  \
# 0          False           False    False                   False
# 1          False           False    False                   False
# 2          False            True    False                    True
# 3           True            True     True                    True
# 4           True            True     True                    True
#
#    power_windows  car_age
# 0          False      3.0
# 1          False      7.0
# 2           True      4.0
# 3           True      4.0
# 4           True      5.0
#
# [5 rows x 29 columns]

# %%
mgn.bar(df)
# Out:
# <Axes: >

# %%
plt.title("Handle Origin Distribution")
plt.hist(df["origin"])
plt.show()

# %%
# plt.title("First Owner Distribution")
# plt.hist(df["first_owner"])
print(df["first_owner"].unique())
# plt.show()
# Out:
# [ True False]

# %%
print(f"Null Values: {df.isnull().sum()}")
# mgn.bar(df)
# Out:
# Null Values: price                     0
# model_year                0
# transmission              0
# fuel_type                 0
# mileage                   0
# brand                     0
# model                     0
# number_of_doors           0
# origin                    0
# first_owner               0
# tax_horsepower            0
# condition                 0
# abs                       0
# airbags                   0
# multimedia                0
# backup_camera             0
# air_conditioning          0
# esp                       0
# aluminum_wheels           0
# speed_limiter             0
# onboard_computer          0
# parking_sensors           0
# cruise_control            0
# leather_seats             0
# navigation_gps            0
# sunroof                   0
# remote_central_locking    0
# power_windows             0
# price_log                 0
# car_age                   0
# dtype: int64

# %%
figs,axes = plt.subplots(1,2,figsize=(12,6))

axes[0].boxplot(df["price"])

axes[1].hist(df["price"],bins=50)

plt.tight_layout()                 # Optional: add gridlines
plt.show()

# %%
figs,axes = plt.subplots(1,2,figsize=(12,6))

axes[0].boxplot(df["price_log"])

axes[1].hist(df["price_log"],bins=50)

plt.tight_layout()                 # Optional: add gridlines
plt.show()
